# %% [markdown]
# # Acne Detection Multi-Class using YOLOv8
#
# Notebook này thực hiện **phát hiện mụn đa lớp** (multi-class acne detection) sử dụng YOLOv8.
#
# ## 🎯 Mục tiêu
# - **Bài toán**: Multi-class acne detection với 6 loại mụn
# - **Classes**: blackheads, dark spot, nodules, papules, pustules, whiteheads
# - **Model**: YOLOv8 (nano, small, medium)
# - **Dataset**: Acne-20 (Roboflow)
#
# ## 📋 Workflow
# 1. Setup và Import Libraries
# 2. Phân tích dữ liệu (Data Analysis)
# 3. Training với YOLOv8
# 4. Đánh giá mô hình (Evaluation)
# 5. Inference và Visualization

# %%
# Install required packages
# %pip install ultralytics opencv-python matplotlib numpy tqdm pandas seaborn scikit-learn
# Out:
# Requirement already satisfied: ultralytics in /opt/homebrew/lib/python3.11/site-packages (8.3.237)
# Requirement already satisfied: opencv-python in /opt/homebrew/lib/python3.11/site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (3.10.7)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (4.66.5)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: seaborn in /opt/homebrew/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: pillow>=7.1.2 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/quangthai/Library/Python/3.11/lib/python/site-packages (from ultralytics) (7.1.1)
# Requirement already satisfied: polars>=0.20.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/quangthai/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /opt/homebrew/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in /Users/quangthai/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Check device availability
import torch

# Check if MPS (Metal Performance Shaders) is available for Mac
if torch.backends.mps.is_available():
    device = 'mps'
    print("✅ GPU (MPS) is available! Using GPU for training.")
elif torch.cuda.is_available():
    device = 'cuda'
    print("✅ CUDA GPU is available!")
else:
    device = 'cpu'
    print("⚠️ Using CPU (slower). Consider using GPU if available.")

print(f"\nDevice selected: {device}")
print(f"PyTorch version: {torch.__version__}")
# Out:
# ✅ GPU (MPS) is available! Using GPU for training.
#
# Device selected: mps
# PyTorch version: 2.9.0

# %%
# Import Libraries
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from ultralytics import YOLO
import random
import yaml
from collections import Counter
import warnings

warnings.filterwarnings('ignore')

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %% [markdown]
# ## 1. Cấu hình Dataset

# %%
# Đường dẫn dataset
dataset_path = "Acne-20"
data_yaml_path = os.path.join(dataset_path, 'data.yaml')

# Kiểm tra dataset có tồn tại không
if not os.path.exists(data_yaml_path):
    print(f"⚠️ Dataset not found at {dataset_path}")
    print("Please ensure the dataset is in the correct location.")
else:
    print(f"✅ Dataset found at: {dataset_path}")
    
    # Đọc data.yaml
    with open(data_yaml_path, 'r') as f:
        data_config = yaml.safe_load(f)
    
    print(f'\n📋 Dataset Config:')
    print(f'   Classes: {data_config.get("nc", "N/A")}')
    print(f'   Class names: {data_config.get("names", "N/A")}')
    
    # Đường dẫn các thư mục
    train_path = os.path.join(dataset_path, 'train')
    val_path = os.path.join(dataset_path, 'valid')
    test_path = os.path.join(dataset_path, 'test')
    
    # Đếm số lượng
    train_images = os.listdir(os.path.join(train_path, 'images')) if os.path.exists(os.path.join(train_path, 'images')) else []
    val_images = os.listdir(os.path.join(val_path, 'images')) if os.path.exists(os.path.join(val_path, 'images')) else []
    test_images = os.listdir(os.path.join(test_path, 'images')) if os.path.exists(os.path.join(test_path, 'images')) else []
    
    print(f'\n📊 Dataset Statistics:')
    print(f'   Training images: {len(train_images)}')
    print(f'   Validation images: {len(val_images)}')
    print(f'   Test images: {len(test_images)}')
    print(f'   Total images: {len(train_images) + len(val_images) + len(test_images)}')
    
    # Lưu class names
    class_names = data_config.get("names", [])
    num_classes = data_config.get("nc", 0)
# Out:
# ✅ Dataset found at: Acne-20
#
# 📋 Dataset Config:
#    Classes: 6
#    Class names: ['blackheads', 'dark spot', 'nodules', 'papules', 'pustules', 'whiteheads']
#
# 📊 Dataset Statistics:
#    Training images: 982
#    Validation images: 197
#    Test images: 92
#    Total images: 1271

# %% [markdown]
# ## 2. Phân tích Dữ liệu (Data Analysis)

# %%
# Phân tích độ cân bằng dữ liệu
def analyze_data_balance(image_dir, label_dir, split_name="Train", class_names=None):
    """Analyze class distribution and data balance"""
    label_files = [f for f in os.listdir(label_dir) if f.endswith('.txt')]
    
    class_counts = Counter()
    images_with_objects = 0
    images_without_objects = 0
    total_objects = 0
    objects_per_image = []
    
    for label_file in label_files:
        label_path = os.path.join(label_dir, label_file)
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if len(lines) == 0:
            images_without_objects += 1
            continue
        
        images_with_objects += 1
        num_objects = len(lines)
        total_objects += num_objects
        objects_per_image.append(num_objects)
        
        for line in lines:
            parts = line.strip().split()
            if len(parts) >= 5:
                cls = int(parts[0])
                class_counts[cls] += 1
    
    print(f"\n📊 {split_name} Set Analysis:")
    print(f"   Total images: {len(label_files)}")
    print(f"   Images with objects: {images_with_objects}")
    print(f"   Images without objects: {images_without_objects}")
    print(f"   Total objects: {total_objects}")
    print(f"   Avg objects per image: {total_objects / images_with_objects if images_with_objects > 0 else 0:.2f}")
    
    print(f"\n📈 Class Distribution ({split_name}):")
    if class_names:
        for cls_id in sorted(class_counts.keys()):
            cls_name = class_names[cls_id] if cls_id < len(class_names) else f"Class {cls_id}"
            count = class_counts[cls_id]
            percentage = (count / total_objects * 100) if total_objects > 0 else 0
            print(f"   {cls_name}: {count} ({percentage:.2f}%)")
    else:
        for cls_id in sorted(class_counts.keys()):
            count = class_counts[cls_id]
            percentage = (count / total_objects * 100) if total_objects > 0 else 0
            print(f"   Class {cls_id}: {count} ({percentage:.2f}%)")
    
    return class_counts, objects_per_image

# Phân tích train, val, test sets
train_label_dir = os.path.join(train_path, 'labels')
val_label_dir = os.path.join(val_path, 'labels')
test_label_dir = os.path.join(test_path, 'labels')

train_class_counts, train_objects_per_img = analyze_data_balance(
    os.path.join(train_path, 'images'), train_label_dir, "Train", class_names
)
val_class_counts, val_objects_per_img = analyze_data_balance(
    os.path.join(val_path, 'images'), val_label_dir, "Validation", class_names
)
test_class_counts, test_objects_per_img = analyze_data_balance(
    os.path.join(test_path, 'images'), test_label_dir, "Test", class_names
)
# Out:
# 📊 Train Set Analysis:
#    Total images: 982
#    Images with objects: 982
#    Images without objects: 0
#    Total objects: 7734
#    Avg objects per image: 7.88
#
# 📈 Class Distribution (Train):
#    blackheads: 723 (9.35%)
#    dark spot: 2630 (34.01%)
#    nodules: 216 (2.79%)
#    papules: 1736 (22.45%)
#    pustules: 1074 (13.89%)
#    whiteheads: 1355 (17.52%)
#
# 📊 Validation Set Analysis:
#    Total images: 197
#    Images with objects: 194
#    Images without objects: 3
#    Total objects: 1097
#    Avg objects per image: 5.65
#
# 📈 Class Distribution (Validation):
#    blackheads: 36 (3.28%)
#    dark spot: 402 (36.65%)
#    nodules: 42 (3.83%)
#    papules: 268 (24.43%)
#    pustules: 161 (14.68%)
#    whiteheads: 188 (17.14%)
#
# 📊 Test Set Analysis:
#    Total images: 92
#    Images with objects: 92
#    Images without objects: 0
#    Total objects: 923
#    Avg objects per image: 10.03
#
# 📈 Class Distribution (Test):
#    blackheads: 34 (3.68%)
#    dark spot: 385 (41.71%)
#    nodules: 46 (4.98%)
#    papules: 185 (20.04%)
#    pustules: 129 (13.98%)
#    whiteheads: 144 (15.60%)

# %%
# Visualization: Class distribution
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Train set
train_classes = sorted(train_class_counts.keys())
train_counts = [train_class_counts[cls] for cls in train_classes]
train_labels = [class_names[cls] if cls < len(class_names) else f"Class {cls}" for cls in train_classes]

axes[0].bar(range(len(train_classes)), train_counts, color='steelblue')
axes[0].set_xticks(range(len(train_classes)))
axes[0].set_xticklabels(train_labels, rotation=45, ha='right')
axes[0].set_title('Train Set - Class Distribution', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Count')
axes[0].grid(axis='y', alpha=0.3)

# Validation set
val_classes = sorted(val_class_counts.keys())
val_counts = [val_class_counts[cls] for cls in val_classes]
val_labels = [class_names[cls] if cls < len(class_names) else f"Class {cls}" for cls in val_classes]

axes[1].bar(range(len(val_classes)), val_counts, color='orange')
axes[1].set_xticks(range(len(val_classes)))
axes[1].set_xticklabels(val_labels, rotation=45, ha='right')
axes[1].set_title('Validation Set - Class Distribution', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Count')
axes[1].grid(axis='y', alpha=0.3)

# Test set
test_classes = sorted(test_class_counts.keys())
test_counts = [test_class_counts[cls] for cls in test_classes]
test_labels = [class_names[cls] if cls < len(class_names) else f"Class {cls}" for cls in test_classes]

axes[2].bar(range(len(test_classes)), test_counts, color='green')
axes[2].set_xticks(range(len(test_classes)))
axes[2].set_xticklabels(test_labels, rotation=45, ha='right')
axes[2].set_title('Test Set - Class Distribution', fontsize=12, fontweight='bold')
axes[2].set_ylabel('Count')
axes[2].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Visualization: Sample images with annotations
def visualize_images_with_labels(image_dir, label_dir, num_samples=8, title="Sample Images", class_names=None):
    """Visualize images with bounding boxes"""
    image_files = [f for f in os.listdir(image_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]
    if len(image_files) == 0:
        print(f"⚠️ No images found in {image_dir}")
        return
    
    selected_images = random.sample(image_files, min(num_samples, len(image_files)))
    
    fig, axes = plt.subplots(2, 4, figsize=(20, 10))
    axes = axes.ravel()
    
    # Color map for different classes
    colors = plt.cm.tab10(np.linspace(0, 1, num_classes))
    
    for i, img_file in enumerate(selected_images):
        img_path = os.path.join(image_dir, img_file)
        label_file = img_file.rsplit('.', 1)[0] + '.txt'
        label_path = os.path.join(label_dir, label_file)
        
        # Read image
        img = cv2.imread(img_path)
        if img is None:
            continue
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        h, w = img_rgb.shape[:2]
        
        # Read labels and draw boxes
        num_objects = 0
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                lines = f.readlines()
            num_objects = len(lines)
            
            for line in lines:
                parts = line.strip().split()
                if len(parts) >= 5:
                    cls = int(parts[0])
                    x_center, y_center, width, height = map(float, parts[1:5])
                    
                    # Convert to pixel coordinates
                    x1 = int((x_center - width/2) * w)
                    y1 = int((y_center - height/2) * h)
                    x2 = int((x_center + width/2) * w)
                    y2 = int((y_center + height/2) * h)
                    
                    # Get color for this class
                    color = (colors[cls][:3] * 255).astype(int).tolist()
                    
                    # Draw bounding box
                    cv2.rectangle(img_rgb, (x1, y1), (x2, y2), color, 2)
                    
                    # Get class name
                    cls_name = class_names[cls] if class_names and cls < len(class_names) else f'Class {cls}'
                    cv2.putText(img_rgb, cls_name, (x1, y1-10), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        
        axes[i].imshow(img_rgb)
        axes[i].axis('off')
        axes[i].set_title(f'{img_file[:30]}...\n{num_objects} objects', fontsize=9)
    
    plt.suptitle(title, fontsize=16, y=1.02)
    plt.tight_layout()
    plt.show()

# Visualize training images
if os.path.exists(os.path.join(train_path, 'images')) and os.path.exists(train_label_dir):
    visualize_images_with_labels(
        os.path.join(train_path, 'images'),
        train_label_dir,
        num_samples=8,
        title="Training Images with Annotations (Multi-Class)",
        class_names=class_names
    )

# %% [markdown]
# ## 3. Training với YOLOv8

# %%
# Chọn model YOLOv8
# Options: 'yolov8n.pt' (nano - fastest), 'yolov8s.pt' (small), 'yolov8m.pt' (medium), 'yolov8l.pt' (large), 'yolov8x.pt' (xlarge)
model_name = 'yolov8n.pt'  # Có thể thay đổi: 'yolov8n.pt', 'yolov8s.pt', 'yolov8m.pt'

print(f"📦 Loading YOLOv8 model: {model_name}")
model = YOLO(model_name)

print(f"✅ Model loaded successfully!")
print(f"   Model type: {model_name}")
print(f"   Device: {device}")
# Out:
# 📦 Loading YOLOv8 model: yolov8n.pt
# ✅ Model loaded successfully!
#    Model type: yolov8n.pt
#    Device: mps

# %%
import torch

if torch.backends.mps.is_available():
    torch.mps.empty_cache()   # PyTorch 2.x hỗ trợ hàm này

# %%
# # Training configuration
# training_config = {
#     'data': data_yaml_path,           # Path to data.yaml
#     'epochs': 100,                     # Number of training epochs
#     'imgsz': 640,                      # Image size
#     'batch': 16,                       # Batch size (adjust based on GPU memory)
#     'device': device,                  # Device: 'mps', 'cuda', or 'cpu'
#     'workers': 0,                      # Number of worker threads
#     'patience': 30,                    # Early stopping patience
#     'save': True,                      # Save checkpoints
#     'save_period': 10,                 # Save checkpoint every N epochs
#     'project': 'runs/detect',          # Project directory
#     'name': 'acne_yolov8_multiclass', # Experiment name
#     'exist_ok': True,                  # Overwrite existing experiment
#     'pretrained': True,                # Use pretrained weights
#     'optimizer': 'AdamW',              # Optimizer: 'SGD', 'Adam', 'AdamW'
#     'lr0': 0.001,                      # Initial learning rate
#     'lrf': 0.01,                       # Final learning rate (lr0 * lrf)
#     # 'momentum': 0.937,                 # SGD momentum
#     # 'weight_decay': 0.0005,            # Weight decay
#     # 'warmup_epochs': 3.0,              # Warmup epochs
#     # 'warmup_momentum': 0.8,            # Warmup initial momentum
#     # 'warmup_bias_lr': 0.1,             # Warmup initial bias lr
#     # 'box': 7.5,                        # Box loss gain
#     # 'cls': 0.5,                        # Class loss gain
#     # 'dfl': 1.5,                        # DFL loss gain
#     # 'hsv_h': 0.015,                    # Image HSV-Hue augmentation
#     # 'hsv_s': 0.7,                      # Image HSV-Saturation augmentation
#     # 'hsv_v': 0.4,                      # Image HSV-Value augmentation
#     # 'degrees': 10.0,                   # Image rotation (+/- deg)
#     # 'translate': 0.1,                  # Image translation (+/- fraction)
#     # 'scale': 0.5,                      # Image scale (+/- gain)
#     # 'shear': 5.0,                      # Image shear (+/- deg)
#     # 'perspective': 0.0,                # Image perspective (+/- fraction)
#     # 'flipud': 0.0,                     # Image flip up-down (probability)
#     # 'fliplr': 0.5,                     # Image flip left-right (probability)
#     # 'mosaic': 1.0,                     # Image mosaic (probability)
#     # 'mixup': 0.1,                      # Image mixup (probability)
#     # 'copy_paste': 0.0,                 # Segment copy-paste (probability)
#     # 'auto_augment': 'randaugment',     # Auto augmentation policy
#     # 'erasing': 0.4,                    # Random erasing probability
#     # 'crop_fraction': 1.0,              # Crop fraction
#     # 'cos_lr': True,                    # Cosine LR scheduler
#     # 'close_mosaic': 10,                # Disable mosaic augmentation for last N epochs
#     # 'resume': False,                   # Resume training from last checkpoint
#     # 'amp': True,                       # Automatic Mixed Precision (AMP) training
#     # 'fraction': 1.0,                   # Dataset fraction to train on
#     # 'profile': False,                  # Profile ONNX and TensorRT speeds
#     # 'freeze': None,                    # Freeze layers: backbone=10, first3=0 1 2
#     # 'multi_scale': False,              # Multi-scale training
#     # 'overlap_mask': True,              # Masks should overlap during training
#     # 'mask_ratio': 4,                   # Mask downsample ratio
#     # 'dropout': 0.0,                    # Use dropout regularization
#     # 'val': True,                       # Validate/test during training
#     # 'split': 'val',                    # Dataset split to use for validation
#     # 'plots': True,                     # Save plots during training
#     # 'verbose': True,                   # Verbose output
# }


training_config = {
    'data': data_yaml_path,
    'epochs': 20,
    'imgsz': 640,
    'batch': 16,
    'device': device,          # 'mps' trên Mac
    'workers': 0,              # bắt buộc cho MPS
    'patience': 30,

    # ---- TẮT OVERHEAD ----
    'plots': False,            # ❌ không vẽ loss/metrics mỗi epoch
    'verbose': False,          # ❌ log rườm rà
    'save_json': False,        # ❌ COCO json (không cần)
    'save_hybrid': False,      # ❌ hybrid labels
    'cache': False,            # ❌ tránh RAM swap trên macOS

    # ---- CHECKPOINT ----
    'save': True,              # giữ best.pt
    'save_period': -1,         # ❌ không save mỗi N epoch (rất tốn I/O)

    # ---- PROJECT ----
    'project': 'runs/detect',
    'name': 'acne_yolov8_multiclass',
    'exist_ok': True,

    # ---- MODEL / OPTIM ----
    'pretrained': True,
    'optimizer': 'AdamW',
    'lr0': 0.001,
    'lrf': 0.01,

    # ---- SPEED TRICKS ----
    'amp': True,               # mixed precision (rất lợi cho MPS)
    'close_mosaic': 10,        # tắt mosaic sớm để ổn định bbox nhỏ
}

print("📋 Training Configuration:")
for key, value in training_config.items():
    print(f"   {key}: {value}")
# Out:
# 📋 Training Configuration:
#    data: Acne-20/data.yaml
#    epochs: 20
#    imgsz: 640
#    batch: 16
#    device: mps
#    workers: 0
#    patience: 30
#    plots: False
#    verbose: False
#    save_json: False
#    save_hybrid: False
#    cache: False
#    save: True
#    save_period: -1
#    project: runs/detect
#    name: acne_yolov8_multiclass
#    exist_ok: True
#    pretrained: True
#    optimizer: AdamW
#    lr0: 0.001
#    lrf: 0.01
#    amp: True
#    close_mosaic: 10

# %%
# Start training
print("🚀 Starting training...")
print(f"   Model: {model_name}")
print(f"   Dataset: {data_yaml_path}")
print(f"   Device: {device}")
print(f"   Classes: {num_classes} ({', '.join(class_names)})")
print("\n" + "="*50)

# Train the model
results = model.train(**training_config)

print("\n" + "="*50)
print("✅ Training completed!")
print(f"   Results saved to: {results.save_dir}")
# Out:
# 🚀 Starting training...
#    Model: yolov8n.pt
#    Dataset: Acne-20/data.yaml
#    Device: mps
#    Classes: 6 (blackheads, dark spot, nodules, papules, pustules, whiteheads)
#
# ==================================================
# WARNING ⚠️ 'save_hybrid' is deprecated and will be removed in the future.
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.9.0 MPS (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Acne-20/data.yaml, degrees=0.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=acne_yolov8_multiclass, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=30, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# Model summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 92.0±12.0 MB/s, size: 18.0 KB)
# train: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/Acne-20/train/labels.cache... 982 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 982/982 4.0Mit/s 0.0s0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 114.5±38.1 MB/s, size: 20.0 KB)
# val: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/Acne-20/valid/labels.cache... 197 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 197/197 813.3Kit/s 0.0s
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      10.4G      2.655      3.711      1.482         81        640: 100% ━━━━━━━━━━━━ 62/62 1.5s/it 1:361.1sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.7s/it 1:08<11.1ss
#                    all        197       1097     0.0223      0.213     0.0255    0.00933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      8.35G      2.499      2.932       1.37         68        640: 100% ━━━━━━━━━━━━ 62/62 1.5s/it 1:351.3sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 16.2s/it 4.8s<1:37WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 9.6s/it 9.8s<48.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.1s/it 14.2s<28.4sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.2s/it 19.0s<18.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 5.9s/it 24.3s<11.8sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.5s/it 31.2s5.4s
#                    all        197       1097      0.242     0.0643     0.0317     0.0103
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      8.36G       2.46       2.83      1.349         65        640: 100% ━━━━━━━━━━━━ 62/62 1.7s/it 1:431.5sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 16.3s/it 4.9s<1:38WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 9.5s/it 9.7s<47.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.7s/it 15.0s<30.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 7.5s/it 22.1s<22.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 7.8s/it 30.8s<15.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.9s/it 41.3s7.9s
#                    all        197       1097      0.221     0.0924       0.03    0.00971
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      8.36G      2.418      2.724      1.344         47        640: 100% ━━━━━━━━━━━━ 62/62 1.6s/it 1:421.5sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 18.7s/it 5.6s<1:52WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.2s/it 10.6s<51.1sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.4s/it 15.1s<29.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.1s/it 19.4s<18.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 5.8s/it 24.6s<11.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.6s/it 31.9s5.7s
#                    all        197       1097      0.059     0.0711     0.0323     0.0113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      8.36G      2.399      2.714      1.327         51        640: 100% ━━━━━━━━━━━━ 62/62 1.8s/it 1:532.2sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 17.0s/it 5.1s<1:42WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 11.0s/it 11.2s<55.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.7s/it 15.7s<30.8sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.9s/it 21.3s<20.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 7.4s/it 30.1s<14.8sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.4s/it 37.8s6.8s
#                    all        197       1097      0.127     0.0895     0.0418     0.0137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      8.36G      2.384      2.581      1.316         75        640: 100% ━━━━━━━━━━━━ 62/62 1.8s/it 1:501.0sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 17.0s/it 5.1s<1:42WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.0s/it 10.2s<50.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.4s/it 14.8s<29.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.4s/it 19.7s<19.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.0s/it 24.9s<12.0sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 5.3s/it 29.1s<5.3sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.6s/it 31.9s
#                    all        197       1097      0.196     0.0772     0.0361     0.0133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      9.94G      2.382      2.538      1.329         75        640: 100% ━━━━━━━━━━━━ 62/62 2.2s/it 2:182.1sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 13.9s/it 4.2s<1:23WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 9.3s/it 9.4s<46.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.5s/it 14.5s<29.8sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.6s/it 19.7s<19.8sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 5.7s/it 24.0s<11.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.4s/it 31.1s5.4s
#                    all        197       1097     0.0996     0.0662     0.0356      0.012
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      8.37G      2.357      2.549       1.31         78        640: 100% ━━━━━━━━━━━━ 62/62 2.3s/it 2:201.5sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 21.4s/it 6.4s<2:09WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 12.8s/it 13.0s<1:04WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 10.0s/it 19.6s<39.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 8.1s/it 25.2s<24.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 7.1s/it 30.6s<14.1sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.5s/it 38.7s6.4s
#                    all        197       1097      0.252     0.0662     0.0467     0.0161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      8.37G       2.34      2.466      1.295         45        640: 100% ━━━━━━━━━━━━ 62/62 2.5s/it 2:362.3ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 19.7s/it 5.9s<1:58WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.3s/it 10.8s<51.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.7s/it 15.7s<30.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.5s/it 20.4s<19.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.2s/it 25.9s<12.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.8s/it 33.6s5.8s
#                    all        197       1097      0.118     0.0811     0.0454     0.0165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20       8.4G       2.33      2.466      1.303         79        640: 100% ━━━━━━━━━━━━ 62/62 2.5s/it 2:363.0sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 16.0s/it 4.8s<1:36WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.1s/it 10.2s<50.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.6s/it 15.1s<30.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.5s/it 20.0s<19.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 7.0s/it 28.2s<13.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 6.3s/it 33.4s<6.3sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.2s/it 36.2s
#                    all        197       1097       0.13     0.0642     0.0392     0.0155
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20       8.4G      2.328      2.421      1.359         52        640: 100% ━━━━━━━━━━━━ 62/62 2.6s/it 2:421.7sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 19.7s/it 5.9s<1:58WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.5s/it 11.0s<52.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.9s/it 16.0s<31.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.8s/it 21.1s<20.4sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.3s/it 26.4s<12.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 5.9s/it 31.5s<5.9sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.9s/it 34.5s
#                    all        197       1097      0.131     0.0578      0.031     0.0118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      8.39G      2.268      2.383      1.346         47        640: 100% ━━━━━━━━━━━━ 62/62 2.4s/it 2:281.5ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 13.8s/it 4.1s<1:23WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 9.3s/it 9.4s<46.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.0s/it 13.9s<28.1sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 5.8s/it 18.1s<17.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.0s/it 24.6s<12.1sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 6.2s/it 31.2s<6.2sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.8s/it 33.8s
#                    all        197       1097      0.118     0.0777     0.0335     0.0122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      8.39G      2.294      2.357       1.33         28        640: 100% ━━━━━━━━━━━━ 62/62 1.7s/it 1:481.5sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 17.7s/it 5.3s<1:46WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 12.9s/it 13.3s<1:05WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 9.0s/it 18.5s<35.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 7.6s/it 24.0s<22.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.8s/it 29.5s<13.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 6.2s/it 34.7s<6.2sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.4s/it 37.5s
#                    all        197       1097      0.152     0.0851     0.0508     0.0186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      8.38G      2.263      2.301      1.327         39        640: 100% ━━━━━━━━━━━━ 62/62 3.3s/it 3:251.2sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 18.2s/it 5.5s<1:49WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 13.1s/it 13.3s<1:05WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 9.1s/it 18.6s<36.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 7.8s/it 24.6s<23.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 8.3s/it 34.2s<16.6sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 8.2s/it 42.3s<8.2sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.5s/it 45.7s
#                    all        197       1097       0.16     0.0728     0.0408     0.0158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      8.39G      2.246      2.277      1.327         35        640: 100% ━━━━━━━━━━━━ 62/62 2.0s/it 2:041.9ss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 19.0s/it 5.7s<1:54WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.6s/it 10.9s<53.0sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 8.7s/it 17.0s<34.8sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 8.8s/it 25.9s<26.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 8.6s/it 34.2s<17.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 7.8s/it 40.7s<7.8sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.2s/it 43.7s
#                    all        197       1097      0.162      0.107     0.0564     0.0208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20       8.4G      2.238      2.234      1.309         40        640: 100% ━━━━━━━━━━━━ 62/62 2.1s/it 2:131.7sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 19.8s/it 5.9s<1:59WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 13.0s/it 13.1s<1:05WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 10.9s/it 21.0s<43.4sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 9.7s/it 28.7s<29.0sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 9.6s/it 38.1s<19.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.8s/it 47.3s8.1s
#                    all        197       1097      0.163      0.103     0.0504     0.0193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      8.39G      2.246      2.214      1.328         44        640: 100% ━━━━━━━━━━━━ 62/62 2.9s/it 2:593.4sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 25.6s/it 7.7s<2:34WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 12.9s/it 13.6s<1:04WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 9.2s/it 19.1s<36.7sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 8.6s/it 26.8s<25.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 8.8s/it 35.8s<17.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 8.7s/it 44.3s<8.7sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.8s/it 47.8s
#                    all        197       1097      0.153      0.102     0.0657     0.0224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      8.39G      2.225      2.175      1.337         53        640: 100% ━━━━━━━━━━━━ 62/62 1.5s/it 1:321.3sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 22.7s/it 6.8s<2:16WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 11.1s/it 11.9s<55.5sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 8.1s/it 16.8s<32.4sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.4s/it 21.1s<19.1sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.0s/it 26.3s<11.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.9s/it 34.0s5.7s
#                    all        197       1097      0.184      0.112     0.0668     0.0227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20       8.5G      2.218      2.143      1.315         34        640: 100% ━━━━━━━━━━━━ 62/62 2.2s/it 2:161.4sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 17.7s/it 5.3s<1:46WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 10.4s/it 10.6s<52.0sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 7.2s/it 14.8s<28.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 6.8s/it 20.7s<20.3sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 6.4s/it 26.5s<12.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.0s/it 35.1s6.6s
#                    all        197       1097       0.18     0.0938     0.0614     0.0217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      8.39G      2.221       2.14      1.306         64        640: 100% ━━━━━━━━━━━━ 62/62 2.5s/it 2:371.9sss
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 23.5s/it 7.0s<2:21WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 12.7s/it 13.2s<1:03WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 9.0s/it 18.6s<36.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 7.7s/it 24.4s<23.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 7.0s/it 30.0s<13.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 7.4s/it 38.9s<7.4sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.0s/it 42.2s
#                    all        197       1097      0.149     0.0986     0.0584       0.02
#
# 20 epochs completed in 0.960 hours.
# Optimizer stripped from /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass/weights/last.pt, 6.2MB
# Optimizer stripped from /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass/weights/best.pt, 6.2MB
#
# Validating /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.9.0 MPS (Apple M4 Pro)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 14% ━╸────────── 1/7 25.8s/it 7.7s<2:35WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 29% ━━━───────── 2/7 17.4s/it 17.6s<1:27WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 43% ━━━━━─────── 3/7 12.0s/it 24.5s<47.9sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 57% ━━━━━━╸───── 4/7 8.3s/it 29.4s<25.0sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 71% ━━━━━━━━╸─── 5/7 7.1s/it 34.7s<14.2sWARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 86% ━━━━━━━━━━── 6/7 6.9s/it 41.0s<6.9sWARNING ⚠️ NMS time limit 2.250s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 6.7s/it 47.2s
#                    all        197       1097      0.195      0.134     0.0798     0.0276
# Speed: 4.7ms preprocess, 79.8ms inference, 0.0ms loss, 134.4ms postprocess per image
#
# ==================================================
# ✅ Training completed!
#    Results saved to: /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass

# %% [markdown]
# ## 4. Đánh giá Mô hình (Model Evaluation)

# %%
# Load best model
best_model_path = os.path.join(results.save_dir, 'weights', 'best.pt')
print(f"📦 Loading best model from: {best_model_path}")

if os.path.exists(best_model_path):
    best_model = YOLO(best_model_path)
    print("✅ Best model loaded successfully!")
else:
    print("⚠️ Best model not found, using last checkpoint...")
    last_model_path = os.path.join(results.save_dir, 'weights', 'last.pt')
    if os.path.exists(last_model_path):
        best_model = YOLO(last_model_path)
        print("✅ Last model loaded successfully!")
    else:
        print("⚠️ No model found, using original model...")
        best_model = model
# Out:
# 📦 Loading best model from: /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_yolov8_multiclass/weights/best.pt
# ✅ Best model loaded successfully!

# %%
# Validate on validation set
print("🔍 Validating model on validation set...")
val_results = best_model.val(
    data=data_yaml_path,
    split='val',
    imgsz=640,
    batch=16,
    conf=0.25,
    iou=0.7,
    device=device,
    plots=True,
    save_json=False,
    save_hybrid=False,
    verbose=True
)

print("\n📊 Validation Results:")
print(f"   mAP50: {val_results.box.map50:.4f}")
print(f"   mAP50-95: {val_results.box.map:.4f}")
print(f"   Precision: {val_results.box.mp:.4f}")
print(f"   Recall: {val_results.box.mr:.4f}")

# Print per-class metrics
if hasattr(val_results.box, 'maps'):
    print("\n📈 Per-Class mAP50:")
    for i, cls_name in enumerate(class_names):
        if i < len(val_results.box.maps):
            print(f"   {cls_name}: {val_results.box.maps[i]:.4f}")
# Out:
# 🔍 Validating model on validation set...
# WARNING ⚠️ 'save_hybrid' is deprecated and will be removed in the future.
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.9.0 MPS (Apple M4 Pro)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 114.1±9.3 MB/s, size: 18.7 KB)
# val: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/Acne-20/valid/labels.cache... 197 images, 3 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 197/197 1.1Mit/s 0.0s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 5.0s/it 1:053.7s3s
#                    all        197       1097      0.271      0.078       0.16      0.068
#             blackheads         23         36      0.125     0.0556     0.0676     0.0165
#              dark spot         95        402      0.439     0.0622      0.244      0.107
#                nodules         28         42          0          0          0          0
#                papules        102        268      0.411       0.19      0.278      0.115
#               pustules         59        161      0.225      0.112       0.14     0.0574
#             whiteheads         52        188      0.429     0.0479      0.231      0.112
# Speed: 7.1ms preprocess, 105.0ms inference, 0.0ms loss, 23.1ms postprocess per image
# Results saved to /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/val2
#
# 📊 Validation Results:
#    mAP50: 0.1601
#    mAP50-95: 0.0680
#    Precision: 0.2714
#    Recall: 0.0780
#
# 📈 Per-Class mAP50:
#    blackheads: 0.0165
#    dark spot: 0.1070
#    nodules: 0.0000
#    papules: 0.1149
#    pustules: 0.0574
#    whiteheads: 0.1124

# %%
# Test on test set
print("🧪 Testing model on test set...")
test_results = best_model.val(
    data=data_yaml_path,
    split='test',
    imgsz=640,
    batch=16,
    conf=0.25,
    iou=0.7,
    device=device,
    plots=True,
    save_json=False,
    save_hybrid=False,
    verbose=True
)

print("\n📊 Test Results:")
print(f"   mAP50: {test_results.box.map50:.4f}")
print(f"   mAP50-95: {test_results.box.map:.4f}")
print(f"   Precision: {test_results.box.mp:.4f}")
print(f"   Recall: {test_results.box.mr:.4f}")

# Print per-class metrics
if hasattr(test_results.box, 'maps'):
    print("\n📈 Per-Class mAP50 (Test Set):")
    for i, cls_name in enumerate(class_names):
        if i < len(test_results.box.maps):
            print(f"   {cls_name}: {test_results.box.maps[i]:.4f}")
# Out:
# 🧪 Testing model on test set...
# WARNING ⚠️ 'save_hybrid' is deprecated and will be removed in the future.
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.9.0 MPS (Apple M4 Pro)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 68.1±28.5 MB/s, size: 17.4 KB)
# val: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/Acne-20/test/labels... 92 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 92/92 2.9Kit/s 0.0s
# val: New cache created: /Users/quangthai/Documents/AI in Bioinfomatics/acne2/Acne-20/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7s/it 34.5s5.9sss
#                    all         92        923      0.275     0.0814       0.17      0.071
#             blackheads         10         34          0          0          0          0
#              dark spot         49        385       0.59     0.0597      0.325      0.142
#                nodules         17         46          0          0          0          0
#                papules         45        185      0.509      0.146      0.306       0.14
#               pustules         32        129      0.299      0.178       0.24      0.104
#             whiteheads         22        144       0.25      0.104      0.146     0.0399
# Speed: 7.9ms preprocess, 87.6ms inference, 0.0ms loss, 29.8ms postprocess per image
# Results saved to /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/val3
#
# 📊 Test Results:
#    mAP50: 0.1695
#    mAP50-95: 0.0710
#    Precision: 0.2746
#    Recall: 0.0814
#
# 📈 Per-Class mAP50 (Test Set):
#    blackheads: 0.0000
#    dark spot: 0.1425
#    nodules: 0.0000
#    papules: 0.1400
#    pustules: 0.1038
#    whiteheads: 0.0399

# %% [markdown]
# ## 5. Inference và Visualization

# %%
# Inference trên test images
test_images_dir = os.path.join(test_path, 'images')
test_image_files = [f for f in os.listdir(test_images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

print(f"📸 Running inference on {len(test_image_files)} test images...")

# Chọn một số ảnh để visualize
num_samples = min(8, len(test_image_files))
sample_images = random.sample(test_image_files, num_samples)

# Run inference
predictions = []
for img_file in sample_images:
    img_path = os.path.join(test_images_dir, img_file)
    results = best_model.predict(
        source=img_path,
        conf=0.25,
        iou=0.7,
        device=device,
        save=False,
        verbose=False
    )
    predictions.append((img_path, results[0]))

print(f"✅ Inference completed on {len(sample_images)} images")
# Out:
# 📸 Running inference on 92 test images...
# ✅ Inference completed on 8 images

# %%
# Visualize predictions
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.ravel()

for i, (img_path, result) in enumerate(predictions):
    # Get annotated image
    annotated_img = result.plot()
    annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
    
    # Count detections per class
    if result.boxes is not None and len(result.boxes) > 0:
        detected_classes = result.boxes.cls.cpu().numpy().astype(int)
        class_counts = Counter(detected_classes)
        detection_info = []
        for cls_id, count in class_counts.items():
            cls_name = class_names[cls_id] if cls_id < len(class_names) else f"Class {cls_id}"
            detection_info.append(f"{cls_name}: {count}")
        title = f"{os.path.basename(img_path)[:30]}...\n" + ", ".join(detection_info)
    else:
        title = f"{os.path.basename(img_path)[:30]}...\nNo detections"
    
    axes[i].imshow(annotated_img_rgb)
    axes[i].axis('off')
    axes[i].set_title(title, fontsize=9)

plt.suptitle('Predictions on Test Images (Multi-Class Acne Detection)', fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
# Detailed inference với confidence scores
def visualize_detections_detailed(img_path, result, class_names, ax):
    """Visualize detections with detailed information"""
    # Get annotated image
    annotated_img = result.plot()
    annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
    
    ax.imshow(annotated_img_rgb)
    ax.axis('off')
    
    # Get detection details
    if result.boxes is not None and len(result.boxes) > 0:
        boxes = result.boxes
        detections_info = []
        
        for box in boxes:
            cls_id = int(box.cls.cpu().numpy()[0])
            conf = float(box.conf.cpu().numpy()[0])
            cls_name = class_names[cls_id] if cls_id < len(class_names) else f"Class {cls_id}"
            detections_info.append(f"{cls_name}: {conf:.2f}")
        
        title = f"{os.path.basename(img_path)}\n" + "\n".join(detections_info[:5])  # Show first 5
        if len(detections_info) > 5:
            title += f"\n... and {len(detections_info) - 5} more"
    else:
        title = f"{os.path.basename(img_path)}\nNo detections"
    
    ax.set_title(title, fontsize=8)

# Visualize với chi tiết
fig, axes = plt.subplots(2, 2, figsize=(16, 16))
axes = axes.ravel()

for i in range(min(4, len(predictions))):
    img_path, result = predictions[i]
    visualize_detections_detailed(img_path, result, class_names, axes[i])

plt.suptitle('Detailed Predictions with Confidence Scores', fontsize=16, y=0.995)
plt.tight_layout()
plt.show()
