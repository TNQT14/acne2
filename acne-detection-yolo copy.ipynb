# %% [markdown]
# # Acne Detection using YOLOv8
#
# This notebook implements acne detection using YOLOv8 (You Only Look Once) object detection model.
#
# ## Dataset
# - Training images: 823
# - Validation images: 56
# - Test images: 48
# - Classes: Acne (1 class)

# %%
# Install required packages
# %pip install ultralytics opencv-python matplotlib numpy tqdm
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.3.237-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /opt/homebrew/lib/python3.11/site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (3.10.7)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (4.66.5)
# Requirement already satisfied: pillow>=7.1.2 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/quangthai/Library/Python/3.11/lib/python/site-packages (from ultralytics) (7.1.1)
# Collecting polars>=0.20.0 (from ultralytics)
#   Using cached polars-1.36.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/quangthai/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Collecting polars-runtime-32==1.36.1 (from polars>=0.20.0->ultralytics)
#   Using cached polars_runtime_32-1.36.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/quangthai/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/homebrew/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Using cached ultralytics-8.3.237-py3-none-any.whl (1.2 MB)
# Using cached polars-1.36.1-py3-none-any.whl (802 kB)
# Using cached polars_runtime_32-1.36.1-cp39-abi3-macosx_11_0_arm64.whl (39.3 MB)
# Using cached ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, polars, ultralytics-thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [ultralytics] [ultralytics]
# Successfully installed polars-1.36.1 polars-runtime-32-1.36.1 ultralytics-8.3.237 ultralytics-thop-2.0.18
# Note: you may need to restart the kernel to use updated packages.

# %%
# Check device availability and configure for Mac M4 GPU
import torch

# Check if MPS (Metal Performance Shaders) is available for Mac M4
if torch.backends.mps.is_available():
    device = 'mps'
    print("✅ GPU (MPS) is available! Using GPU for training.")
    print("   This will significantly speed up training on Mac M4.")
elif torch.cuda.is_available():
    device = 'cuda'
    print("✅ CUDA GPU is available!")
else:
    device = 'cpu'
    print("⚠️ Using CPU (slower). Consider using GPU if available.")

print(f"\nDevice selected: {device}")
print(f"MPS built: {torch.backends.mps.is_built()}")
print(f"PyTorch version: {torch.__version__}")
# Out:
# ✅ GPU (MPS) is available! Using GPU for training.
#    This will significantly speed up training on Mac M4.
#
# Device selected: mps
# MPS built: True
# PyTorch version: 2.9.0

# %%
# Import Libraries
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO
import random

# %% [markdown]
# ## 1. Data Exploration

# %%
# Define data paths
train_path = 'data-2/train'
val_path = 'data-2/valid'
test_path = 'data-2/test'

# Count images and labels
train_images = os.listdir(os.path.join(train_path, 'images'))
train_labels = os.listdir(os.path.join(train_path, 'labels'))
val_images = os.listdir(os.path.join(val_path, 'images'))
val_labels = os.listdir(os.path.join(val_path, 'labels'))
test_images = os.listdir(os.path.join(test_path, 'images'))
test_labels = os.listdir(os.path.join(test_path, 'labels'))

print(f'Training images: {len(train_images)}, labels: {len(train_labels)}')
print(f'Validation images: {len(val_images)}, labels: {len(val_labels)}')
print(f'Test images: {len(test_images)}, labels: {len(test_labels)}')
# Out:
# Training images: 823, labels: 823
# Validation images: 56, labels: 56
# Test images: 48, labels: 48

# %%
# Visualize sample training images
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.ravel()

for i in range(8):
    img_file = random.choice(train_images)
    img_path = os.path.join(train_path, 'images', img_file)
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    axes[i].imshow(img_rgb)
    axes[i].axis('off')
    axes[i].set_title(f'Image: {img_file[:30]}...')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Hyperparameter Configuration

# %%
## Hyperparameter Configuration Options

# Chọn một trong các config dưới đây:

# === CONFIG 1: Balanced (Recommended) ===
TRAIN_CONFIG = {
    'model': 'yolov8s.pt',      # Small model - cân bằng tốt giữa tốc độ và độ chính xác
    'imgsz': 720,               # Tăng resolution để detect đối tượng nhỏ tốt hơn
    'batch': 12,                # Giảm batch khi tăng image size
    'lr0': 0.001,               # Learning rate thấp hơn để học ổn định
    'epochs': 200,
    'patience': 30,             # Early stopping patience
    'degrees': 10.0,            # Rotation augmentation
    'shear': 5.0,               # Shear augmentation
    'mixup': 0.1,               # Mixup augmentation
    'cos_lr': True,             # Cosine learning rate schedule
}

# === CONFIG 2: High Accuracy (Slower, Better Results) ===
# TRAIN_CONFIG = {
#     'model': 'yolov8m.pt',      # Medium model - độ chính xác cao hơn
#     'imgsz': 1024,              # Resolution cao nhất
#     'batch': 8,                 # Batch nhỏ hơn do model lớn
#     'lr0': 0.0005,              # Learning rate thấp hơn
#     'epochs': 400,
#     'patience': 40,
#     'degrees': 15.0,
#     'shear': 10.0,
#     'mixup': 0.2,
#     'cos_lr': True,
# }

# === CONFIG 3: Fast Training (Lower Accuracy) ===
# TRAIN_CONFIG = {
#     'model': 'yolov8n.pt',      # Nano model - nhanh nhất
#     'imgsz': 640,               # Resolution thấp
#     'batch': 32,                # Batch lớn
#     'lr0': 0.01,                # Learning rate cao
#     'epochs': 200,
#     'patience': 50,
#     'degrees': 0.0,
#     'shear': 0.0,
#     'mixup': 0.0,
#     'cos_lr': False,
# }

print("✅ Selected Configuration:")
for key, value in TRAIN_CONFIG.items():
    print(f"   {key}: {value}")
# Out:
# ✅ Selected Configuration:
#    model: yolov8s.pt
#    imgsz: 720
#    batch: 12
#    lr0: 0.001
#    epochs: 200
#    patience: 30
#    degrees: 10.0
#    shear: 5.0
#    mixup: 0.1
#    cos_lr: True

# %% [markdown]
# ## 3. Initialize YOLO Model

# %%
# Initialize YOLOv8 model với config đã chọn
model = YOLO(TRAIN_CONFIG['model'])
print(f"✅ Model initialized: {TRAIN_CONFIG['model']}")
print("   Model ready for training with optimized parameters!")
# Out:
# ✅ Model initialized: yolov8s.pt
#    Model ready for training with optimized parameters!

# %% [markdown]
# ## 4. Train the Model
#
# **Note:**
# - Training will use GPU (MPS) on Mac M4 if available, which is 3-5x faster than CPU.
# - Using optimized hyperparameters for better accuracy and reduced false positives.

# %%
# Train the model with OPTIMIZED parameters for better results
results = model.train(
    data='data-2/data.yaml',
    
    # === Epochs & Early Stopping ===
    epochs=TRAIN_CONFIG['epochs'],
    patience=TRAIN_CONFIG['patience'],
    
    # === Image Size ===
    imgsz=TRAIN_CONFIG['imgsz'],  # Tăng resolution để detect đối tượng nhỏ tốt hơn
    
    # === Batch Size ===
    batch=TRAIN_CONFIG['batch'],
    
    # === Learning Rate ===
    lr0=TRAIN_CONFIG['lr0'],      # Learning rate thấp hơn để học ổn định
    lrf=0.01,                      # Learning rate final
    momentum=0.937,
    weight_decay=0.0005,
    
    # === Augmentation - Tăng để giảm overfitting ===
    hsv_h=0.015,                   # Hue augmentation
    hsv_s=0.7,                     # Saturation augmentation
    hsv_v=0.4,                     # Value augmentation
    degrees=TRAIN_CONFIG['degrees'], # Rotation augmentation
    translate=0.1,                 # Translation
    scale=0.5,                     # Scale augmentation
    shear=TRAIN_CONFIG['shear'],   # Shear augmentation
    perspective=0.0,               # Perspective
    flipud=0.0,                    # Vertical flip
    fliplr=0.5,                    # Horizontal flip
    mosaic=1.0,                    # Mosaic augmentation
    mixup=TRAIN_CONFIG['mixup'],   # Mixup augmentation
    copy_paste=0.0,                # Copy-paste
    
    # === Loss Weights ===
    box=7.5,                       # Box loss weight
    cls=0.5,                       # Classification loss weight
    dfl=1.5,                       # DFL loss weight
    
    # === Other Optimizations ===
    device=device,
    workers=4,
    amp=True,                      # Mixed precision training
    save=True,
    plots=True,
    cache=False,                   # Set True nếu có đủ RAM
    
    # === Learning Rate Schedule ===
    cos_lr=TRAIN_CONFIG['cos_lr'], # Cosine learning rate schedule
    
    # === Optimizer ===
    optimizer='AdamW',             # AdamW optimizer (tốt cho dataset nhỏ)
    
    # === Validation ===
    val=True,
    split='val',
    
    # === Name ===
    name='acne_detection_optimized',
)

print("\n✅ Training completed!")
print(f"Best model saved at: {results.save_dir}/weights/best.pt")
print(f"Last model saved at: {results.save_dir}/weights/last.pt")
# Out:
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.9.0 MPS (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=12, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=data-2/data.yaml, degrees=10.0, deterministic=True, device=mps, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=720, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=acne_detection_optimized5, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_detection_optimized5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=5.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# WARNING ⚠️ imgsz=[720] must be multiple of max stride 32, updating to [736]
# train: Fast image access ✅ (ping: 0.0±0.1 ms, read: 115.6±57.1 MB/s, size: 38.0 KB)
# train: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/data-2/train/labels.cache... 823 images, 12 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 823/823 4.0Mit/s 0.0s0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 188.4±75.5 MB/s, size: 39.5 KB)
# val: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/data-2/valid/labels.cache... 56 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 56/56 421.7Kit/s 0.0s
# Plotting labels to /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_detection_optimized5/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.00046875), 63 bias(decay=0.0)
# Image sizes 736 train, 736 val
# Using 0 dataloader workers
# Logging results to /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_detection_optimized5
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      9.37G       2.13      2.019       1.56        223        736: 100% ━━━━━━━━━━━━ 69/69 1.3s/it 1:301.3sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s9.1ss
#                    all         56        643      0.389      0.426      0.354      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      9.47G      1.966      1.789      1.444        153        736: 100% ━━━━━━━━━━━━ 69/69 1.1s/it 1:171.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 11.5s/it 3.5s<23.1sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.0s/it 9.0s7.5s
#                    all         56        643      0.267      0.459      0.212     0.0705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      9.39G      1.978      1.761      1.478         84        736: 100% ━━━━━━━━━━━━ 69/69 1.3s/it 1:321.5sss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 14.6s/it 4.4s<29.1sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.5s/it 10.4s.4s
#                    all         56        643      0.346      0.365      0.253     0.0901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      8.39G      1.931      1.748      1.438        141        736: 100% ━━━━━━━━━━━━ 69/69 1.3s/it 1:301.3sss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 13.1s/it 3.9s<26.2sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.4s/it 10.1s.3s
#                    all         56        643      0.417      0.379      0.328      0.119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      8.48G      1.902       1.69      1.452        109        736: 100% ━━━━━━━━━━━━ 69/69 1.3s/it 1:311.4sss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 18.9s/it 5.7s<37.9sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 11.1s/it 11.3s<11.1sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.7s
#                    all         56        643      0.399      0.383      0.318      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      9.45G       1.91      1.662      1.442         99        736: 100% ━━━━━━━━━━━━ 69/69 1.8s/it 2:012.0sss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 18.7s/it 5.6s<37.5sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 11.1s/it 11.3s<11.1sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.7s
#                    all         56        643      0.404      0.339      0.274      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      8.46G      1.882      1.651      1.424        149        736: 100% ━━━━━━━━━━━━ 69/69 1.6s/it 1:501.8sss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 15.6s/it 4.7s<31.3sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 8.9s/it 9.2s<8.9sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                    all         56        643      0.487      0.299      0.287       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      8.41G      1.878      1.648      1.415         94        736: 100% ━━━━━━━━━━━━ 69/69 1.9s/it 2:082.2sss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 16.7s/it 5.0s<33.5sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 9.1s/it 9.5s<9.1sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.4s
#                    all         56        643       0.33      0.306      0.214     0.0832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      9.41G      1.874      1.617      1.412        143        736: 100% ━━━━━━━━━━━━ 69/69 2.2s/it 2:322.5ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 18.8s/it 5.7s<37.7sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 11.4s/it 11.6s<11.4sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.0s/it 14.9s
#                    all         56        643      0.397      0.247      0.222     0.0874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      8.49G      1.885      1.632      1.422        113        736: 100% ━━━━━━━━━━━━ 69/69 2.1s/it 2:252.3ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 18.3s/it 5.5s<36.5sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.9s/it 14.7s<11.4s
#                    all         56        643      0.466      0.285      0.274      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      9.44G      1.831       1.61      1.393         75        736: 100% ━━━━━━━━━━━━ 69/69 2.4s/it 2:492.8ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 18.9s/it 5.7s<37.9sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 11.7s/it 11.9s<11.7sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 5.2s/it 15.6s
#                    all         56        643      0.333      0.295      0.216     0.0753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      8.42G      1.818      1.596      1.374         96        736: 100% ━━━━━━━━━━━━ 69/69 2.4s/it 2:462.8ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 16.1s/it 4.8s<32.1sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 8.5s/it 8.9s<8.5sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.0s/it 11.9s
#                    all         56        643      0.503      0.275      0.256      0.101
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      9.42G      1.861      1.607      1.399        118        736: 100% ━━━━━━━━━━━━ 69/69 2.8s/it 3:143.9ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 19.3s/it 5.8s<38.6sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 11.1s/it 11.4s<11.1sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8s/it 14.5s
#                    all         56        643      0.464      0.272      0.256      0.119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      9.42G      1.821      1.578      1.365        116        736: 100% ━━━━━━━━━━━━ 69/69 3.0s/it 3:294.2ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 15.1s/it 4.5s<30.2sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 8.4s/it 8.7s<8.4sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                    all         56        643      0.397      0.232      0.201      0.091
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      9.46G      1.831      1.554      1.376         91        736: 100% ━━━━━━━━━━━━ 69/69 3.5s/it 4:044.0ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 18.0s/it 5.4s<36.1sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 11.0s/it 11.2s<11.0sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.8s/it 14.5s
#                    all         56        643      0.424      0.221       0.21     0.0918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      8.43G      1.793      1.547       1.36        115        736: 100% ━━━━━━━━━━━━ 69/69 4.2s/it 4:524.4ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 19.0s/it 5.7s<38.1sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 10.0s/it 10.4s<10.0sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.4s/it 13.3s
#                    all         56        643      0.416       0.23      0.177     0.0768
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      8.43G      1.818      1.543      1.381        163        736: 100% ━━━━━━━━━━━━ 69/69 3.9s/it 4:284.3ss
# WARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 17.8s/it 5.3s<35.7sWARNING ⚠️ NMS time limit 3.200s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 10.5s/it 10.7s<10.5sWARNING ⚠️ NMS time limit 2.400s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.6s/it 13.9s
#                    all         56        643      0.485       0.25      0.241      0.102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      9.42G      1.786      1.544      1.367        225        736: 42% ━━━━━─────── 29/69 2.7s/it 2:07<1:487
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Train the model with OPTIMIZED parameters for better results
# ----> 2 results = model.train(
#       3     data='data-2/data.yaml',
#       4
#       5     # === Epochs & Early Stopping ===
#       6     epochs=TRAIN_CONFIG['epochs'],
#       7     patience=TRAIN_CONFIG['patience'],
#       8
#       9     # === Image Size ===
#      10     imgsz=TRAIN_CONFIG['imgsz'],  # Tăng resolution để detect đối tượng nhỏ tốt hơn
#      11
#      12     # === Batch Size ===
#      13     batch=TRAIN_CONFIG['batch'],
#      14
#      15     # === Learning Rate ===
#      16     lr0=TRAIN_CONFIG['lr0'],      # Learning rate thấp hơn để học ổn định
#      17     lrf=0.01,                      # Learning rate final
#      18     momentum=0.937,
#      19     weight_decay=0.0005,
#      20
#      21     # === Augmentation - Tăng để giảm overfitting ===
#      22     hsv_h=0.015,                   # Hue augmentation
#      23     hsv_s=0.7,                     # Saturation augmentation
#      24     hsv_v=0.4,                     # Value augmentation
#      25     degrees=TRAIN_CONFIG['degrees'], # Rotation augmentation
#      26     translate=0.1,                 # Translation
#      27     scale=0.5,                     # Scale augmentation
#      28     shear=TRAIN_CONFIG['shear'],   # Shear augmentation
#      29     perspective=0.0,               # Perspective
#      30     flipud=0.0,                    # Vertical flip
#      31     fliplr=0.5,                    # Horizontal flip
#      32     mosaic=1.0,                    # Mosaic augmentation
#      33     mixup=TRAIN_CONFIG['mixup'],   # Mixup augmentation
#      34     copy_paste=0.0,                # Copy-paste
#      35
#      36     # === Loss Weights ===
#      37     box=7.5,                       # Box loss weight
#      38     cls=0.5,                       # Classification loss weight
#      39     dfl=1.5,                       # DFL loss weight
#      40
#      41     # === Other Optimizations ===
#      42     device=device,
#      43     workers=4,
#      44     amp=True,                      # Mixed precision training
#      45     save=True,
#      46     plots=True,
#      47     cache=False,                   # Set True nếu có đủ RAM
#      48
#      49     # === Learning Rate Schedule ===
#      50     cos_lr=TRAIN_CONFIG['cos_lr'], # Cosine learning rate schedule
#      51
#      52     # === Optimizer ===
#      53     optimizer='AdamW',             # AdamW optimizer (tốt cho dataset nhỏ)
#      54
#      55     # === Validation ===
#      56     val=True,
#      57     split='val',
#      58
#      59     # === Name ===
#      60     name='acne_detection_optimized',
#      61 )
#      63 print("\n✅ Training completed!")
#      64 print(f"Best model saved at: {results.save_dir}/weights/best.pt")
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/engine/model.py:773, in Model.train(self, trainer, **kwargs)
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     771     self.model = self.trainer.model
# --> 773 self.trainer.train()
#     774 # Update model and cfg after training
#     775 if RANK in {-1, 0}:
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/engine/trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/engine/trainer.py:427, in BaseTrainer._do_train(self)
#     425     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     426 else:
# --> 427     loss, self.loss_items = self.model(batch)
#     428 self.loss = loss.sum()
#     429 if RANK != -1:
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/tasks.py:136, in BaseModel.forward(self, x, *args, **kwargs)
#     123 """Perform forward pass of the model for either training or inference.
#     124
#     125 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)    133     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     134 """
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 136     return self.loss(x, *args, **kwargs)
#     137 return self.predict(x, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/nn/tasks.py:328, in BaseModel.loss(self, batch, preds)
#     326 if preds is None:
#     327     preds = self.forward(batch["img"])
# --> 328 return self.criterion(preds, batch)
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/utils/loss.py:270, in v8DetectionLoss.__call__(self, preds, batch)
#     266 pred_bboxes = self.bbox_decode(anchor_points, pred_distri)  # xyxy, (b, h*w, 4)
#     267 # dfl_conf = pred_distri.view(batch_size, -1, 4, self.reg_max).detach().softmax(-1)
#     268 # dfl_conf = (dfl_conf.amax(-1).mean(-1) + dfl_conf.amax(-1).amin(-1)) / 2
# --> 270 _, target_bboxes, target_scores, fg_mask, _ = self.assigner(
#     271     # pred_scores.detach().sigmoid() * 0.8 + dfl_conf.unsqueeze(-1) * 0.2,
#     272     pred_scores.detach().sigmoid(),
#     273     (pred_bboxes.detach() * stride_tensor).type(gt_bboxes.dtype),
#     274     anchor_points * stride_tensor,
#     275     gt_labels,
#     276     gt_bboxes,
#     277     mask_gt,
#     278 )
#     280 target_scores_sum = max(target_scores.sum(), 1)
#     282 # Cls loss
#     283 # loss[1] = self.varifocal_loss(pred_scores, target_scores, target_labels) / target_scores_sum  # VFL way
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File /opt/homebrew/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/utils/tal.py:79, in TaskAlignedAssigner.forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      70     return (
#      71         torch.full_like(pd_scores[..., 0], self.num_classes),
#      72         torch.zeros_like(pd_bboxes),
#    (...)     75         torch.zeros_like(pd_scores[..., 0]),
#      76     )
#      78 try:
# ---> 79     return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      80 except torch.cuda.OutOfMemoryError:
#      81     # Move tensors to CPU, compute, then move back to original device
#      82     LOGGER.warning("CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU")
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/utils/tal.py:105, in TaskAlignedAssigner._forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      87 def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#      88     """Compute the task-aligned assignment.
#      89
#      90     Args:
#    (...)    103         target_gt_idx (torch.Tensor): Target ground truth indices with shape (bs, num_total_anchors).
#     104     """
# --> 105     mask_pos, align_metric, overlaps = self.get_pos_mask(
#     106         pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt
#     107     )
#     109     target_gt_idx, fg_mask, mask_pos = self.select_highest_overlaps(mask_pos, overlaps, self.n_max_boxes)
#     111     # Assigned target
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/utils/tal.py:141, in TaskAlignedAssigner.get_pos_mask(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt)
#     139 mask_in_gts = self.select_candidates_in_gts(anc_points, gt_bboxes)
#     140 # Get anchor_align metric, (b, max_num_obj, h*w)
# --> 141 align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_in_gts * mask_gt)
#     142 # Get topk_metric mask, (b, max_num_obj, h*w)
#     143 mask_topk = self.select_topk_candidates(align_metric, topk_mask=mask_gt.expand(-1, -1, self.topk).bool())
#
# File /opt/homebrew/lib/python3.11/site-packages/ultralytics/utils/tal.py:172, in TaskAlignedAssigner.get_box_metrics(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_gt)
#     170 ind[1] = gt_labels.squeeze(-1)  # b, max_num_obj
#     171 # Get the scores of each grid for each gt cls
# --> 172 bbox_scores[mask_gt] = pd_scores[ind[0], :, ind[1]][mask_gt]  # b, max_num_obj, h*w
#     174 # (b, max_num_obj, 1, 4), (b, 1, h*w, 4)
#     175 pd_boxes = pd_bboxes.unsqueeze(1).expand(-1, self.n_max_boxes, -1, -1)[mask_gt]
#
# RuntimeError: shape mismatch: value tensor of shape [13440] cannot be broadcast to indexing result of shape [17311]

# %%
## Load Best Model After Training

# Tự động load best model sau khi training
results_dir = results.save_dir if 'results' in locals() else 'runs/detect/acne_detection_optimized'
best_model_path = os.path.join(results_dir, 'weights', 'best.pt')
last_model_path = os.path.join(results_dir, 'weights', 'last.pt')

# Kiểm tra và load best model
if os.path.exists(best_model_path):
    model = YOLO(best_model_path)
    print(f"✅ Loaded BEST model from: {best_model_path}")
    print("   This model has the highest mAP50-95 score during training.")
elif os.path.exists(last_model_path):
    model = YOLO(last_model_path)
    print(f"⚠️ Best model not found. Loaded LAST model from: {last_model_path}")
else:
    print("⚠️ No saved model found. Using current model.")

# Hiển thị thông tin model
print(f"\nModel info:")
print(f"  - Device: {device}")
print(f"  - Ready for inference")
# Out:
# ✅ Loaded BEST model from: /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/acne_detection_optimized4/weights/best.pt
#    This model has the highest mAP50-95 score during training.
#
# Model info:
#   - Device: mps
#   - Ready for inference

# %% [markdown]
# ## 5. Evaluate the Model

# %%
# Evaluate on test set (using GPU if available)
metrics = model.val(data='data-2/data.yaml', split='test', device=device)
print(f"\nTest Results:")
print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"Precision: {metrics.box.mp:.4f}")
print(f"Recall: {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.9.0 MPS (Apple M4 Pro)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 169.2±101.2 MB/s, size: 42.5 KB)
# val: Scanning /Users/quangthai/Documents/AI in Bioinfomatics/acne2/data-2/test/labels... 48 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 48/48 2.5Kit/s 0.0s
# val: New cache created: /Users/quangthai/Documents/AI in Bioinfomatics/acne2/data-2/test/labels.cache
# WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 33% ━━━━──────── 1/3 41.3s/it 12.4s<1:23WARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 67% ━━━━━━━━──── 2/3 16.1s/it 19.0s<16.1sWARNING ⚠️ NMS time limit 2.800s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 9.1s/it 27.2s
#                    all         48        607      0.402      0.227      0.174     0.0655
# Speed: 1.1ms preprocess, 111.0ms inference, 0.0ms loss, 206.6ms postprocess per image
# Results saved to /Users/quangthai/Documents/AI in Bioinfomatics/acne2/runs/detect/val
#
# Test Results:
# mAP50: 0.1742
# mAP50-95: 0.0655
# Precision: 0.4019
# Recall: 0.2273

# %% [markdown]
# ## 6. Visualize Training Results

# %%
# Display training results
results_dir = 'runs/detect/acne_detection_optimized'  # Updated path

# Plot training curves
if os.path.exists(os.path.join(results_dir, 'results.png')):
    img = cv2.imread(os.path.join(results_dir, 'results.png'))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(15, 10))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title('Training Results', fontsize=16)
    plt.show()
else:
    print(f"Training results not found at: {results_dir}")
# Out:
# Training results not found at: runs/detect/acne_detection_optimized

# %%
# Display confusion matrix
results_dir = 'runs/detect/acne_detection_optimized'  # Updated path
if os.path.exists(os.path.join(results_dir, 'confusion_matrix.png')):
    img = cv2.imread(os.path.join(results_dir, 'confusion_matrix.png'))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(12, 10))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title('Confusion Matrix', fontsize=16)
    plt.show()
else:
    print(f"Confusion matrix not found at: {results_dir}")
# Out:
# Confusion matrix not found at: runs/detect/acne_detection_optimized

# %% [markdown]
# ## 7. Make Predictions on Test Images

# %%
# Load model for inference (nếu chưa load ở trên)
results_dir = 'runs/detect/acne_detection_optimized'
best_model_path = os.path.join(results_dir, 'weights', 'best.pt')
last_model_path = os.path.join(results_dir, 'weights', 'last.pt')

if not hasattr(model, 'ckpt_path') or model.ckpt_path is None:
    if os.path.exists(best_model_path):
        model = YOLO(best_model_path)
        print(f"✅ Loaded BEST model: {best_model_path}")
    elif os.path.exists(last_model_path):
        model = YOLO(last_model_path)
        print(f"✅ Loaded LAST model: {last_model_path}")
    else:
        print("⚠️ Using current model")
else:
    print("✅ Model already loaded")
# Out:
# ✅ Model already loaded

# %%
# Function to detect acne with optimized parameters
def detect_acne(img_path, model, conf_threshold=0.4, iou_threshold=0.45):
    """
    Detect acne in an image with optimized parameters
    - conf_threshold: Tăng từ 0.25 lên 0.4 để giảm false positives
    - iou_threshold: Giảm từ 0.7 xuống 0.45 để giữ nhiều detections hơn
    Uses GPU (MPS) on Mac M4 for faster inference
    """
    # Read image
    img = cv2.imread(img_path)
    if img is None:
        print(f"Error: Could not read image {img_path}")
        return None
    
    # Tối ưu inference parameters
    results = model.predict(
        source=img, 
        conf=conf_threshold,      # Confidence threshold (tăng để giảm false positives)
        iou=iou_threshold,        # IoU threshold cho NMS
        device=device,
        verbose=False,
        agnostic_nms=False,       # Class-aware NMS
        max_det=300,              # Maximum detections per image
    )
    
    # Get annotated image
    annotated_img = results[0].plot()
    annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
    
    # Print detection info
    num_detections = len(results[0].boxes)
    print(f"Detected {num_detections} acne(s) in {os.path.basename(img_path)}")
    
    return annotated_img_rgb, results[0]

# %%
# Test on a single image
test_image_files = os.listdir(os.path.join(test_path, 'images'))
test_img_path = os.path.join(test_path, 'images', test_image_files[0])

annotated_img, results = detect_acne(test_img_path, model)
if annotated_img is not None:
    plt.figure(figsize=(12, 8))
    plt.imshow(annotated_img)
    plt.axis('off')
    plt.title(f'Detection Results: {os.path.basename(test_img_path)}', fontsize=14)
    plt.show()
    
    # Print bounding box details
    if len(results.boxes) > 0:
        print(f"\nBounding boxes:")
        for i, box in enumerate(results.boxes):
            conf = box.conf[0].item()
            cls = int(box.cls[0].item())
            print(f"  Acne {i+1}: Confidence = {conf:.3f}")
# Out:
# Detected 22 acne(s) in acne-151_jpg.rf.638c693eb9342b4800bd8b1758e566e1.jpg
# Bounding boxes:
#   Acne 1: Confidence = 0.850
#   Acne 2: Confidence = 0.848
#   Acne 3: Confidence = 0.784
#   Acne 4: Confidence = 0.769
#   Acne 5: Confidence = 0.718
#   Acne 6: Confidence = 0.707
#   Acne 7: Confidence = 0.679
#   Acne 8: Confidence = 0.668
#   Acne 9: Confidence = 0.588
#   Acne 10: Confidence = 0.588
#   Acne 11: Confidence = 0.569
#   Acne 12: Confidence = 0.528
#   Acne 13: Confidence = 0.501
#   Acne 14: Confidence = 0.492
#   Acne 15: Confidence = 0.487
#   Acne 16: Confidence = 0.452
#   Acne 17: Confidence = 0.445
#   Acne 18: Confidence = 0.445
#   Acne 19: Confidence = 0.435
#   Acne 20: Confidence = 0.427
#   Acne 21: Confidence = 0.410
#   Acne 22: Confidence = 0.404

# %% [markdown]
# ## 8. Batch Prediction on Test Images

# %%
# Select random test images for visualization
num_samples = min(8, len(test_image_files))
selected_images = random.sample(test_image_files, num_samples)

# Create visualization
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.ravel()

for i, img_file in enumerate(selected_images):
    img_path = os.path.join(test_path, 'images', img_file)
    annotated_img, _ = detect_acne(img_path, model)
    
    if annotated_img is not None:
        axes[i].imshow(annotated_img)
        axes[i].axis('off')
        axes[i].set_title(f'{img_file[:25]}...', fontsize=10)

plt.tight_layout()
plt.suptitle('Acne Detection on Test Images', fontsize=16, y=1.02)
plt.show()
# Out:
# WARNING ⚠️ NMS time limit 2.050s exceeded
# Detected 29 acne(s) in acne-286_jpeg.rf.1b6bcca440593ac6e33617083f34a4c5.jpg
# WARNING ⚠️ NMS time limit 2.050s exceeded
# Detected 42 acne(s) in acne-329_jpeg.rf.705fb900ba87dc12538508177c52c8a6.jpg
# WARNING ⚠️ NMS time limit 2.050s exceeded
# Detected 8 acne(s) in acne-370_jpeg.rf.a774873f1db723d298598b08cfc47315.jpg
# Detected 5 acne(s) in acne-440_jpeg.rf.74f7f4b7cabd5d5e65c05367b20cb921.jpg
# Detected 8 acne(s) in acne-276_jpeg.rf.9d0990f99dee0e0ec17d89fd07384e0b.jpg
# Detected 38 acne(s) in acne-202_jpg.rf.3cb4d03fc5719519ae3f8319099eddef.jpg
# Detected 16 acne(s) in acne-112_jpeg.rf.a03c796422719e964f46be1c118861bc.jpg
# Detected 62 acne(s) in acne-140_jpg.rf.785b2c29676c422c6a1cdbe6708f86e8.jpg

# %% [markdown]
# ## 9. Export Model (Optional)

# %%
# Export model to different formats
# Uncomment the format you need:

# Export to ONNX (for inference with ONNX Runtime)
# model.export(format='onnx')

# Export to TensorFlow Lite (for mobile devices)
# model.export(format='tflite')

# Export to CoreML (for iOS)
# model.export(format='coreml')

# Export to TensorRT (for NVIDIA GPUs)
# model.export(format='engine')

print("Model export options available. Uncomment the format you need.")
# Out:
# Model export options available. Uncomment the format you need.

# %% [markdown]
# ## Summary
#
# This notebook demonstrates:
# - ✅ YOLOv8 model training for acne detection with optimized hyperparameters
# - ✅ Model evaluation and metrics
# - ✅ Visualization of predictions
# - ✅ Batch processing of test images
# - ✅ Early stopping and automatic best model loading
# - ✅ Optimized inference parameters to reduce false positives
#
# ### Optimizations Applied:
# - **Model**: yolov8s (better accuracy than nano)
# - **Image Size**: 832px (higher resolution for small objects)
# - **Learning Rate**: 0.001 (more stable training)
# - **Augmentation**: Enhanced (rotation, shear, mixup)
# - **Cosine LR Schedule**: Enabled for better convergence
# - **Confidence Threshold**: 0.4 (reduced false positives)
#
# The trained model is saved in `runs/detect/acne_detection_optimized/weights/best.pt`
